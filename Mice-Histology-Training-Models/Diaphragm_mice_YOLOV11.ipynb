# %%
import zipfile

zip_file_path = "/content/drive/MyDrive/PhD/BioViosion Segmentation/Mouse Samples/Diaphragm/Diaphragm_mice.v1i.yolov11.zip"
extract_location = "/content/drive/MyDrive/PhD/BioViosion Segmentation/Mouse Samples/Diaphragm"

try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_location)
    print(f"Successfully extracted {zip_file_path} to {extract_location}")
except FileNotFoundError:
    print(f"Error: The file {zip_file_path} was not found.")
except zipfile.BadZipFile:
    print(f"Error: The file {zip_file_path} is not a valid ZIP file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Successfully extracted /content/drive/MyDrive/PhD/BioViosion Segmentation/Mouse Samples/Diaphragm/Diaphragm_mice.v1i.yolov11.zip to /content/drive/MyDrive/PhD/BioViosion Segmentation/Mouse Samples/Diaphragm

# %%
# !pip install --upgrade ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 41.1/235.7 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolo11x.yaml')
model = YOLO('yolo11x.pt')

# Train the model
train_results = model.train(
    data="/content/drive/MyDrive/PhD/BioViosion Segmentation/Mouse Samples/Diaphragm/data.yaml",
    epochs=1000,
    patience=100,
    batch=32,
    imgsz=640,
    device=0,
    lr0=0.0001,
    lrf=0.001,
    amp=True,
    project="/content/drive/MyDrive/PhD/BioViosion Segmentation/Mouse Samples/Diaphragm/results",  # Explicitly save results here
    name="exp",  # YOLO will create 'exp', 'exp2', etc., automatically
    exist_ok=False  # Set True if you want to overwrite existing results
)
# Out:
# ...
# 100%|██████████| 109M/109M [00:00<00:00, 462MB/s]
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
