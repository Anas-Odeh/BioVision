# %%
# !pip install --upgrade ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 41.0/235.7 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolo11x.yaml')
model = YOLO('yolo11x.pt')

# Train the model
train_results = model.train(
    data="/content/drive/MyDrive/PhD/BioViosion Segmentation/Human samples/Thyroid/YOLOv11/data.yaml",
    epochs=1000,
    patience=100,
    batch=32,
    imgsz=640,
    device=0,
    lr0=0.0001,
    lrf=0.001,
    amp=True,
    project="/content/drive/MyDrive/PhD/BioViosion Segmentation/Human samples/Thyroid/YOLOv11/results",  # Explicitly save results here
    name="exp",  # YOLO will create 'exp', 'exp2', etc., automatically
    exist_ok=False  # Set True if you want to overwrite existing results
)
# Out:
# ...
# 100%|██████████| 109M/109M [00:00<00:00, 324MB/s]
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
